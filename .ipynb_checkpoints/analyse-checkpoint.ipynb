# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt 

import numpy as np

# %%
df = pd.read_csv("C:/Users/User/Desktop/bundestag/whole.csv", sep=";", encoding="Latin-1")

# %%
df.head()
# Out:
#                                                 text       datum  \
# 0  Wow. Bremer AfD noch kaputter als bekannt: Tro...  2021-07-30
# 1  Mein Plakat ist da:\r\nAlles muss gerechter we...  2021-07-30
# 2  Besuch von Bremer Aktiven der @IPPNWgermany, d...  2021-07-28
# 3  Bundesgerichtshof bestätigt, dass #CumEx krimi...  2021-07-28
# 4  Queer-Austausch zum #CSD-Wochenende mit dem Ju...  2021-07-23
#
#               name         fullname fraktion  \
# 0  @DorisAchelwilm  Doris Achelwilm    Linke
# 1  @DorisAchelwilm  Doris Achelwilm    Linke
# 2  @DorisAchelwilm  Doris Achelwilm    Linke
# 3  @DorisAchelwilm  Doris Achelwilm    Linke
# 4  @DorisAchelwilm  Doris Achelwilm    Linke
#
#                                         cleaned_text  sentiment  \
# 0  Wow. Bremer AfD noch kaputter als bekannt: Tro...         -1
# 1  Mein Plakat ist da:\r\nAlles muss gerechter we...          0
# 2  Besuch von Bremer Aktiven der  den Ärzt*innen ...          0
# 3  Bundesgerichtshof bestätigt, dass CumEx krimin...          0
# 4  Queer-Austausch zum CSD-Wochenende mit dem Jug...          0
#
#                                             sequence    Arbeit  Außenpolitik  \
# 0  Wow. Bremer AfD noch kaputter als bekannt: Tro...  0.151105      0.053366
# 1  Mein Plakat ist da:\r\nAlles muss gerechter we...  0.176695      0.037150
# 2  Besuch von Bremer Aktiven der  den Ärzt*innen ...  0.190059      0.079888
# 3  Bundesgerichtshof bestätigt, dass CumEx krimin...  0.204993      0.003231
# 4  Queer-Austausch zum CSD-Wochenende mit dem Jug...  0.114864      0.029825
#
#    ...     Rente  Sicherheit   Steuern  Tierwohl    Umwelt   Verkehr  \
# 0  ...  0.041906    0.244514  0.039496  0.019228  0.032279  0.031881
# 1  ...  0.033550    0.050284  0.112969  0.007082  0.027157  0.023583
# 2  ...  0.021858    0.264878  0.019492  0.006364  0.129829  0.009922
# 3  ...  0.006659    0.080376  0.321194  0.002848  0.002497  0.002898
# 4  ...  0.027294    0.155424  0.032612  0.027148  0.034693  0.042567
#
#    Wirtschaft    Wohnen  Zuwanderung       topic
# 0    0.029670  0.043883     0.036484  Sicherheit
# 1    0.031350  0.042189     0.025740      Arbeit
# 2    0.017372  0.011602     0.005983  Sicherheit
# 3    0.051125  0.003357     0.002493     Steuern
# 4    0.025853  0.038699     0.059710  Sicherheit
#
# [5 rows x 28 columns]

# %%
df["fraktion"].value_counts()
# Out:
# FDP        904
# CDU/CSU    817
# Linke      729
# SPD        715
# Grüne      708
# AfD        609
# fraktio    203
# Name: fraktion, dtype: int64

# %%
df.groupby(["fraktion"]).agg({"fullname": "size"})
# Out:
#           fullname
# fraktion
# AfD            609
# CDU/CSU        817
# FDP            904
# Grüne          708
# Linke          729
# SPD            715
# fraktio        203

# %%
df.groupby(["fraktion"]).agg({"fullname": "size"}) / df.groupby(["fraktion"]).agg({"fullname": "nunique"})
# Out:
#            fullname
# fraktion
# AfD       12.428571
# CDU/CSU   11.840580
# FDP       15.859649
# Grüne     13.882353
# Linke     13.754717
# SPD       10.671642
# fraktio   50.750000

# %%
by_fraktion = df.groupby(["fraktion"]).agg({"sentiment": [np.mean, np.size]}).reset_index()
by_fraktion.columns = by_fraktion.columns.droplevel(0)
by_fraktion.sort_values(by="mean", ascending=False)
by_fraktion.columns = ["fraktion", "mean", "size"]
by_fraktion
# Out:
#   fraktion      mean  size
# 0      AfD -0.221675   609
# 1  CDU/CSU -0.062424   817
# 2      FDP -0.042035   904
# 3    Grüne -0.104520   708
# 4    Linke -0.148148   729
# 5      SPD -0.149650   715
# 6  fraktio -0.295567   203

# %%
sns.set_palette(sns.color_palette(["blue", "black", "yellow", "green", "pink", "red", "gray"]))

sns.barplot(y="mean", x="fraktion", data=by_fraktion)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
by_fraktion_p = df.groupby(["fraktion", "fullname"]).agg({"sentiment": [np.mean, np.size]}).reset_index()
by_fraktion_p.columns = by_fraktion_p.columns.droplevel(0)
by_fraktion_p.columns = ["fraktion", "fullname", "mean", "size"]
by_fraktion_p.sort_values(by=["mean", "size"], inplace=True)
by_fraktion_p = by_fraktion_p[by_fraktion_p["size"] > 3]
by_fraktion_p.head(10)
# Out:
#     fraktion                  fullname      mean  size
# 327      SPD            Metin Hakverdi -0.600000     5
# 6        AfD  Birgit Malsack-Winkemann -0.571429     7
# 212    Grüne           Oliver Krischer -0.555556    18
# 8        AfD            Corinna Miazga -0.545455    11
# 265    Linke                 Petra Pau -0.545455    11
# 68   CDU/CSU             Florian Oßner -0.500000     4
# 204    Grüne                Lisa Badum -0.500000     4
# 329      SPD           Michael Schrodi -0.500000     4
# 332      SPD               Niels Annen -0.500000     4
# 262    Linke             Nicole Gohlke -0.500000    10

# %%
by_fraktion_p.sort_values(by=["mean", "size"], inplace=True, ascending=False)
by_fraktion_p.head(10)
# Out:
#     fraktion              fullname      mean  size
# 175    Grüne     Agnieszka Brugger  0.500000     4
# 152      FDP          Marcus Faber  0.400000     5
# 63   CDU/CSU          Dorothee Bär  0.388889    18
# 121      FDP     Benjamin Strasser  0.333333     9
# 293      SPD         Detlef Müller  0.300000    10
# 62   CDU/CSU        Daniela Ludwig  0.272727    11
# 178    Grüne  Beate Müller-Gemmeke  0.250000     8
# 55   CDU/CSU        Antje Tillmann  0.250000     4
# 64   CDU/CSU  Elisabeth Motschmann  0.250000     4
# 110  CDU/CSU       Thomas Heilmann  0.250000     4

# %%
sns.barplot(x="mean", y="fullname", data=by_fraktion_p)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
result = df.pivot_table(index=["fraktion"], columns='topic', aggfunc='size', fill_value=0)
result
# Out:
# topic     Arbeit  Außenpolitik  Digitalisierung  Europäische Union  Familie  \
# fraktion
# AfD          267            16                8                 14       12
# CDU/CSU      344            14               26                 15       17
# FDP          413            18               26                 26       16
# Grüne        250            13               14                 13       19
# Linke        288            15               10                 20       17
# SPD          315            15               13                  4       20
# fraktio      107             2                3                  7        2
#
# topic     Finanzen  Gesundheit  Integration  Klima  Pflege  Rente  Sicherheit  \
# fraktion
# AfD             11          57           17     13      21     16          81
# CDU/CSU         11          63           49     16      37     16         112
# FDP             38          67           28     25      38     13          91
# Grüne           17          40           21     94      27      9          90
# Linke           39          54           23     55      14     14          84
# SPD              9          66           31     26      34     15          99
# fraktio          1          17            7      7       5      4          16
#
# topic     Steuern  Tierwohl  Umwelt  Verkehr  Wirtschaft  Wohnen  Zuwanderung
# fraktion
# AfD             7         4      20        7           5      10           23
# CDU/CSU        10         7      18       19           7      25           11
# FDP            12         0      15       28          19      24            7
# Grüne           9         2      45       24           1      16            4
# Linke           9         4      28        8           7      31            9
# SPD             7         1      24        7           3      13           13
# fraktio         2         1      10        1           5       5            1

# %%
relative = result.apply(lambda x: x / result.sum(axis=1))
relative_by_topic = relative / relative.mean()
relative_by_topic.reset_index(inplace=True)
relative_by_topic
# Out:
# topic fraktion    Arbeit  Außenpolitik  Digitalisierung  Europäische Union  \
# 0          AfD  1.012139      1.381844         0.656005           1.031648
# 1      CDU/CSU  0.972037      0.901285         1.589227           0.823929
# 2          FDP  1.054698      1.047274         1.436282           1.290701
# 3        Grüne  0.815179      0.965754         0.987483           0.824007
# 4        Linke  0.912035      1.082231         0.685026           1.231185
# 5          SPD  1.017070      1.103421         0.907971           0.251058
# 6      fraktio  1.216842      0.518191         0.738006           1.547472
#
# topic   Familie  Finanzen  Gesundheit  Integration     Klima    Pflege  \
# 0      0.943496  0.749991    1.188101     0.757626  0.429821  0.960413
# 1      0.996330  0.559051    0.978845     1.627785  0.394329  1.261350
# 2      0.847477  1.745403    0.940810     0.840645  0.556843  1.170768
# 3      1.284981  0.997002    0.717170     0.805024  2.673349  1.062151
# 4      1.116600  2.221353    0.940290     0.856295  1.519135  0.534880
# 5      1.339369  0.522657    1.171746     1.176735  0.732198  1.324429
# 6      0.471748  0.204543    1.063037     0.935890  0.694325  0.686009
#
# topic     Rente  Sicherheit   Steuern  Tierwohl    Umwelt   Verkehr  \
# 0      1.384468    1.121215  0.984718  1.544272  0.897074  0.642075
# 1      1.031996    1.155626  1.048598  2.014453  0.601819  1.299082
# 2      0.757801    0.848583  1.137218  0.000000  0.453250  1.730194
# 3      0.669868    1.071595  1.089031  0.664168  1.736180  1.893578
# 4      1.012000    0.971344  1.057660  1.290071  1.049170  0.613010
# 5      1.105517    1.167214  0.838732  0.328833  0.916897  0.546886
# 6      1.038351    0.664424  0.844044  1.158204  1.345610  0.275175
#
# topic  Wirtschaft    Wohnen  Zuwanderung
# 0        0.740258  0.633278     2.641633
# 1        0.772514  1.180130     0.941743
# 2        1.895028  1.023893     0.541616
# 3        0.127350  0.871562     0.395174
# 4        0.865767  1.640008     0.863529
# 5        0.378308  0.701212     1.271743
# 6        2.220775  0.949917     0.344561

# %%
sns.barplot(y="Arbeit", x="fraktion", data=relative_by_topic)
